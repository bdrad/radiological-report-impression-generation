# %%
import pandas as pd
import numpy as np
import Levenshtein
from scipy.stats import mannwhitneyu
import numpy as np
import pingouin as pg
import evaluate
rouge = evaluate.load('rouge')

# %%
demographics_reports = pd.read_csv('data/demographics_reports.csv')
demographics_reports = demographics_reports.rename(columns={'id': 'report_id', 'pathology': 'Pathology'})
evaluations = pd.read_csv('data/evaluations.csv')
evaluations = evaluations.drop_duplicates(subset=['user_id', 'report_id']).reset_index(drop=True)
ratings = evaluations.merge(demographics_reports)

clinical_accuracy_mapping = {
    "accurate": 4,
    "mostly accurate": 3,
    "inaccurate": 2,
    "frankly misleading": 1
}

stylistic_quality_mapping = {
    "satisfactory": 4,
    "mostly satisfactory": 3,
    "unsatisfactory": 2,
    "very unsatisfactory": 1
}

grammatical_accuracy_mapping = {
    "no errors": 4,
    "one error": 3,
    "multiple errors": 2,
}

ratings['clinical_accuracy_int'] = ratings['clinical_accuracy'].map(clinical_accuracy_mapping)
ratings['stylistic_quality_int'] = ratings['stylistic_quality'].map(stylistic_quality_mapping)
ratings['grammatical_accuracy_int'] = ratings['grammatical_accuracy'].map(grammatical_accuracy_mapping)

# %%
import evaluate

def compute_rouge(hypothesis, reference):
    rouge_scores = rouge.compute(predictions=[hypothesis], references=[reference])
    return rouge_scores['rouge1'], rouge_scores['rouge2'], rouge_scores['rougeL']

def edit_distance(str1, str2):
    str1_words = str1.split(' ')
    str2_words = str2.split(' ')
    return Levenshtein.distance(str1_words, str2_words)

ratings.loc[ratings['original'] == 1, 'edit_distance'] = \
ratings.apply(lambda row: edit_distance(row['original_impression'], row['edited_impression']), axis=1)
ratings.loc[ratings['original'] == 0, 'edit_distance'] = \
ratings.apply(lambda row: edit_distance(row['predicted_impression'], row['edited_impression']), axis=1)

for index, row in ratings.iterrows():
    if row['original'] == 1:
        rouge_1, rouge_2, rouge_L = compute_rouge(row['original_impression'], row['edited_impression'])
    else:
        rouge_1, rouge_2, rouge_L = compute_rouge(row['predicted_impression'], row['edited_impression'])
    
    ratings.at[index, 'rouge_1'] = rouge_1
    ratings.at[index, 'rouge_2'] = rouge_2
    ratings.at[index, 'rouge_L'] = rouge_L

# %%
def bootstrap_ci(data, n_bootstraps=10000, ci=95):
    bootstrapped_means = []
    for _ in range(n_bootstraps):
        sample = np.random.choice(data, replace=True, size=len(data))
        bootstrapped_means.append(np.mean(sample))
    lower_bound = np.percentile(bootstrapped_means, (100-ci)/2)
    upper_bound = np.percentile(bootstrapped_means, 100-(100-ci)/2)
    return lower_bound, upper_bound

# %%
metrics = ['clinical_accuracy_int', 'grammatical_accuracy_int', 'stylistic_quality_int', 'edit_time', 'edit_distance', 'rouge_1', 'rouge_2', 'rouge_L']

pathology_mask = {
    'Cancer/Staging': ratings['Pathology'] == 'Cancer Staging',
    'Acute/Emergent': ratings['Pathology'] == 'Acute/Emergent',
    'Other': (ratings['Pathology'] == 'Interstitial Lung Disease')|\
    (ratings['Pathology'] == 'Nodules')|\
    (ratings['Pathology'] == 'Lung Transplant')|\
    (ratings['Pathology'] == 'Aneurysm')
}

author_mask = {
    'LLM': ratings['original'] == 0,
    'Radiologist': ratings['original'] == 1
}

for pathology in pathology_mask:
    print('='*20)
    print(pathology)
    print('='*20)
    for metric in metrics:
        print('-'*20)
        print(metric)
        print('-'*20)
        mean_rating = ratings[pathology_mask[pathology]][metric][author_mask['LLM']].mean()
        ci = bootstrap_ci(ratings[pathology_mask[pathology]][metric][author_mask['LLM']])
        print('LLM: {:.2f} {}'.format(mean_rating, ci))
        mean_rating = ratings[pathology_mask[pathology]][metric][author_mask['Radiologist']].mean()
        ci = bootstrap_ci(ratings[pathology_mask[pathology]][metric][author_mask['Radiologist']])
        print('Radiologist: {:.2f} {}'.format(mean_rating, ci))
# Out:
# ====================
# Cancer/Staging
# ====================
# --------------------
# clinical_accuracy_int
# --------------------
# LLM: 3.59 (3.4125, 3.7375)
# Radiologist: 3.67 (3.3333333333333335, 3.9)
# --------------------
# grammatical_accuracy_int
# --------------------
# LLM: 3.92 (3.8625, 3.975)
# Radiologist: 3.83 (3.7, 3.966666666666667)
# --------------------
# stylistic_quality_int
# --------------------
# LLM: 3.35 (3.2, 3.5)
# Radiologist: 3.53 (3.3666666666666667, 3.7)
# --------------------
# edit_time
# --------------------
# LLM: 22.22 (15.966228125000002, 29.2341125)
# Radiologist: 16.34 (8.682991666666666, 25.1161)
# --------------------
# edit_distance
# --------------------
# LLM: 12.75 (9.2125, 16.6)
# Radiologist: 8.43 (4.7, 13.366666666666667)
# --------------------
# rouge_1
# --------------------
# LLM: 0.85 (0.8020128167408307, 0.896143043626636)
# Radiologist: 0.89 (0.8305249469133024, 0.9434378903578805)
# --------------------
# rouge_2
# --------------------
# LLM: 0.80 (0.7462125761058286, 0.8605715383349096)
# Radiologist: 0.86 (0.7797222709447041, 0.9235047831472145)
# --------------------
# rouge_L
# --------------------
# LLM: 0.84 (0.7874044606370677, 0.8889283246487187)
# Radiologist: 0.89 (0.8233403386379489, 0.9416340604758078)
# ====================
# Acute/Emergent
# ====================
# --------------------
# clinical_accuracy_int
# --------------------
# LLM: 3.64 (3.453333333333333, 3.8)
# Radiologist: 3.71 (3.4285714285714284, 3.914285714285714)
# --------------------
# grammatical_accuracy_int
# --------------------
# LLM: 3.96 (3.9066666666666667, 4.0)
# Radiologist: 3.86 (3.7142857142857144, 3.9714285714285715)
# --------------------
# stylistic_quality_int
# --------------------
# LLM: 3.49 (3.3333333333333335, 3.64)
# Radiologist: 3.37 (3.142857142857143, 3.5714285714285716)
# --------------------
# edit_time
# --------------------
# LLM: 10.94 (7.329, 14.700890000000001)
# Radiologist: 11.62 (6.757692857142858, 17.771528571428572)
# --------------------
# edit_distance
# --------------------
# LLM: 8.39 (5.506666666666667, 11.573333333333334)
# Radiologist: 6.63 (3.8857142857142857, 9.772142857142848)
# --------------------
# rouge_1
# --------------------
# LLM: 0.87 (0.8160603348819339, 0.9167598513846328)
# Radiologist: 0.89 (0.8219051632161093, 0.9446591171703245)
# --------------------
# rouge_2
# --------------------
# LLM: 0.83 (0.7594525233539833, 0.8882360191767085)
# Radiologist: 0.84 (0.7547910368708203, 0.91493333139873)
# --------------------
# rouge_L
# --------------------
# LLM: 0.85 (0.795626650744878, 0.9043517206868271)
# Radiologist: 0.88 (0.8087164811011041, 0.9425439440452152)
# ====================
# Other
# ====================
# --------------------
# clinical_accuracy_int
# --------------------
# LLM: 3.40 (3.1333333333333333, 3.6222222222222222)
# Radiologist: 3.86 (3.657142857142857, 4.0)
# --------------------
# grammatical_accuracy_int
# --------------------
# LLM: 3.87 (3.7333333333333334, 3.977777777777778)
# Radiologist: 3.91 (3.8, 4.0)
# --------------------
# stylistic_quality_int
# --------------------
# LLM: 3.18 (2.933333333333333, 3.4)
# Radiologist: 3.71 (3.5428571428571427, 3.8857142857142857)
# --------------------
# edit_time
# --------------------
# LLM: 23.55 (15.658188888888889, 31.876144444444442)
# Radiologist: 9.24 (3.8196714285714286, 16.82663571428571)
# --------------------
# edit_distance
# --------------------
# LLM: 18.11 (11.244444444444444, 25.822222222222223)
# Radiologist: 2.54 (1.2285714285714286, 4.085714285714285)
# --------------------
# rouge_1
# --------------------
# LLM: 0.83 (0.7722271253604879, 0.8883850381651505)
# Radiologist: 0.90 (0.8456909472748838, 0.9567666670635068)
# --------------------
# rouge_2
# --------------------
# LLM: 0.78 (0.70388453662068, 0.8532673237218573)
# Radiologist: 0.85 (0.7500487478751522, 0.9278477001464975)
# --------------------
# rouge_L
# --------------------
# LLM: 0.82 (0.7502260411828007, 0.8822615181428024)
# Radiologist: 0.89 (0.8221282147904893, 0.953807758118421)

# %%
metrics = ['clinical_accuracy_int', 'grammatical_accuracy_int', 'stylistic_quality_int', 'edit_time', 'edit_distance']

length_mask = {
    'Short': ratings['Length'] == 'Short',
    'Medium': ratings['Length'] == 'Medium',
    'Long': ratings['Length'] == 'Long'
}

author_mask = {
    'LLM': ratings['original'] == 0,
    'Radiologist': ratings['original'] == 1
}

for length in length_mask:
    print('='*20)
    print(length)
    print('='*20)
    for metric in metrics:
        print('-'*20)
        print(metric)
        print('-'*20)
        mean_rating = ratings[length_mask[length]][metric][author_mask['LLM']].mean()
        ci = bootstrap_ci(ratings[length_mask[length]][metric][author_mask['LLM']])
        print('LLM: {:.2f} {}'.format(mean_rating, ci))
        mean_rating = ratings[length_mask[length]][metric][author_mask['Radiologist']].mean()
        ci = bootstrap_ci(ratings[length_mask[length]][metric][author_mask['Radiologist']])
        print('Radiologist: {:.2f} {}'.format(mean_rating, ci))
# Out:
# ====================
# Short
# ====================
# --------------------
# clinical_accuracy_int
# --------------------
# LLM: 3.66 (3.4714285714285715, 3.8142857142857145)
# Radiologist: 3.77 (3.5142857142857142, 3.9714285714285715)
# --------------------
# grammatical_accuracy_int
# --------------------
# LLM: 3.89 (3.8, 3.9571428571428573)
# Radiologist: 3.89 (3.742857142857143, 4.0)
# --------------------
# stylistic_quality_int
# --------------------
# LLM: 3.37 (3.1857142857142855, 3.5428571428571427)
# Radiologist: 3.63 (3.4571428571428573, 3.8)
# --------------------
# edit_time
# --------------------
# LLM: 21.66 (14.915828571428571, 29.139975)
# Radiologist: 10.25 (4.9159500000000005, 16.687507142857136)
# --------------------
# edit_distance
# --------------------
# LLM: 15.07 (10.4, 20.385714285714286)
# Radiologist: 5.66 (2.9714285714285715, 9.028571428571428)
# ====================
# Medium
# ====================
# --------------------
# clinical_accuracy_int
# --------------------
# LLM: 3.45 (3.230769230769231, 3.646153846153846)
# Radiologist: 3.66 (3.3714285714285714, 3.8857142857142857)
# --------------------
# grammatical_accuracy_int
# --------------------
# LLM: 3.94 (3.876923076923077, 3.9846153846153847)
# Radiologist: 3.89 (3.7714285714285714, 3.9714285714285715)
# --------------------
# stylistic_quality_int
# --------------------
# LLM: 3.25 (3.046153846153846, 3.4307692307692306)
# Radiologist: 3.37 (3.142857142857143, 3.5714285714285716)
# --------------------
# edit_time
# --------------------
# LLM: 16.32 (11.334361538461538, 21.95294999999999)
# Radiologist: 14.87 (8.749107142857143, 22.260885714285717)
# --------------------
# edit_distance
# --------------------
# LLM: 13.97 (9.215384615384615, 19.123461538461534)
# Radiologist: 7.31 (4.057142857142857, 11.657857142857132)
# ====================
# Long
# ====================
# --------------------
# clinical_accuracy_int
# --------------------
# LLM: 3.58 (3.3846153846153846, 3.753846153846154)
# Radiologist: 3.83 (3.6, 4.0)
# --------------------
# grammatical_accuracy_int
# --------------------
# LLM: 3.95 (3.8923076923076922, 4.0)
# Radiologist: 3.83 (3.7, 3.966666666666667)
# --------------------
# stylistic_quality_int
# --------------------
# LLM: 3.48 (3.3230769230769233, 3.6153846153846154)
# Radiologist: 3.63 (3.466666666666667, 3.8)
# --------------------
# edit_time
# --------------------
# LLM: 16.63 (11.158115384615385, 22.51681923076923)
# Radiologist: 11.36 (4.8283, 20.527033333333332)
# --------------------
# edit_distance
# --------------------
# LLM: 7.71 (5.492307692307692, 10.123076923076923)
# Radiologist: 4.00 (2.1666666666666665, 6.066666666666666)

# %%
print('='*20)
print('Overall')
print('='*20)
for metric in metrics:
    print('-'*20)
    print(metric)
    print('-'*20)
    mean_rating = ratings[metric][author_mask['LLM']].mean()
    ci = bootstrap_ci(ratings[metric][author_mask['LLM']])
    print('LLM: {:.2f} {}'.format(mean_rating, ci))
    mean_rating = ratings[metric][author_mask['Radiologist']].mean()
    ci = bootstrap_ci(ratings[metric][author_mask['Radiologist']])
    print('Radiologist: {:.2f} {}'.format(mean_rating, ci))
    
    u_statistic, p_value = mannwhitneyu(ratings[metric][author_mask['LLM']], ratings[metric][author_mask['Radiologist']])

    print('P-value: {}'.format(p_value))
# Out:
# ====================
# Overall
# ====================
# --------------------
# clinical_accuracy_int
# --------------------
# LLM: 3.56 (3.455, 3.67)
# Radiologist: 3.75 (3.6, 3.88)
# P-value: 0.009424586098816032
# --------------------
# grammatical_accuracy_int
# --------------------
# LLM: 3.92 (3.885, 3.96)
# Radiologist: 3.87 (3.79, 3.94)
# P-value: 0.1471535431371396
# --------------------
# stylistic_quality_int
# --------------------
# LLM: 3.37 (3.265, 3.465)
# Radiologist: 3.54 (3.43, 3.65)
# P-value: 0.07709473103329303
# --------------------
# edit_time
# --------------------
# LLM: 18.29 (14.78817375, 22.051862500000006)
# Radiologist: 12.20 (8.52618, 16.447459999999996)
# P-value: 0.12613235133533962
# --------------------
# edit_distance
# --------------------
# LLM: 12.32 (9.825, 14.945)
# Radiologist: 5.74 (4.07, 7.71)
# P-value: 0.0036961643221417925
# --------------------
# rouge_1
# --------------------
# LLM: 0.85 (0.8228875880583361, 0.8822708602163793)
# Radiologist: 0.89 (0.859601033284577, 0.9269065351922172)
# P-value: 0.1655705024668085
# --------------------
# rouge_2
# --------------------
# LLM: 0.81 (0.770380106624758, 0.8441275768229016)
# Radiologist: 0.85 (0.7960080988913182, 0.8929523674323593)
# P-value: 0.23353301187870112
# --------------------
# rouge_L
# --------------------
# LLM: 0.84 (0.8071939764883002, 0.871293122351829)
# Radiologist: 0.89 (0.8475716697961243, 0.9230570330853162)
# P-value: 0.15564245567604956

# %% [markdown]
# ## FIGURE 3 - Lowest Clinical Accuracy (Model)

# %%
report_id = ratings.loc[ratings["original"] == 0, ['report_id', 'clinical_accuracy_int']] \
    .groupby('report_id') \
    .mean() \
    .sort_values(['clinical_accuracy_int', 'report_id'], ascending=True) \
    .head(5).index[0]
lowest_clinical_acc_model = ratings[ratings['report_id'] == report_id].sort_values(by=['user_id'])

# %%
print('Model:')
print(lowest_clinical_acc_model.iloc[i]['predicted_impression'])
for i in range(5):
    print('-'*40)
    print('Radiologist', i+1)
    print('-'*40)
    print('-'*40)
    print('Edited:')
    print(lowest_clinical_acc_model.iloc[i]['edited_impression'])
    print('-'*40)
    print('Clinical Accuracy: ', lowest_clinical_acc_model.iloc[i]['clinical_accuracy_int'], '/ 4')
    print('Edit Time: ', lowest_clinical_acc_model.iloc[i]['edit_time'])
    print('ROUGE-L: ', lowest_clinical_acc_model.iloc[i]['rouge_L'])
# Out:
# Model:
# 1. Compared to 1/26/2022, no significant change in extensive lower lobe predominant groundglass and peribronchovascular reticulation with associated traction bronchiectasis/bronchiolectasis. Findings are most consistent with UIP pattern interstitial lung disease.
# ----------------------------------------
# Radiologist 1
# ----------------------------------------
# ----------------------------------------
# Edited:
# 1. Compared to 1/26/2022, no significant change in extensive lower lobe predominant groundglass and peribronchovascular reticulation with associated traction bronchiectasis/bronchiolectasis. Findings are most consistent with NSIP pattern interstitial lung disease.
# ----------------------------------------
# Clinical Accuracy:  2 / 4
# Edit Time:  3.11
# ROUGE-L:  0.9696969696969697
# ----------------------------------------
# Radiologist 2
# ----------------------------------------
# ----------------------------------------
# Edited:
# 1. Compared to 1/26/2022, no significant change in extensive lower lobe predominant groundglass and peribronchovascular reticulation with associated traction bronchiectasis/bronchiolectasis. Findings are most consistent with and NSIP pattern interstitial lung disease which may be due to underlying connective tissue disease given patulous appearance of the esophagus.
# ----------------------------------------
# Clinical Accuracy:  1 / 4
# Edit Time:  36.19
# ROUGE-L:  0.7804878048780488
# ----------------------------------------
# Radiologist 3
# ----------------------------------------
# ----------------------------------------
# Edited:
# 1. Compared to 1/26/2022, unchanged extent of NSIP pattern interstitial lung disease.
# ----------------------------------------
# Clinical Accuracy:  1 / 4
# Edit Time:  19.88
# ROUGE-L:  0.42553191489361697
# ----------------------------------------
# Radiologist 4
# ----------------------------------------
# ----------------------------------------
# Edited:
# 1. Compared to 1/26/2022, no significant change in extensive lower lobe predominant groundglass and peribronchovascular reticulation with associated traction bronchiectasis/bronchiolectasis. Findings are most consistent with 'probable' UIP pattern interstitial lung disease.
# ----------------------------------------
# Clinical Accuracy:  3 / 4
# Edit Time:  18.79
# ROUGE-L:  0.9850746268656716
# ----------------------------------------
# Radiologist 5
# ----------------------------------------
# ----------------------------------------
# Edited:
# 1. Compared to 1/26/2022, no significant change in extensive lower lobe predominant groundglass and peribronchovascular reticulation with associated traction bronchiectasis/bronchiolectasis. Findings are most consistent with UIP pattern interstitial lung disease.
# ----------------------------------------
# Clinical Accuracy:  4 / 4
# Edit Time:  0.0
# ROUGE-L:  1.0

# %% [markdown]
# ## FIGURE 4 - Lowest Stylistic Quality (Model)

# %%
report_id = ratings.loc[ratings["original"] == 0, ['report_id', 'stylistic_quality_int']] \
    .groupby('report_id') \
    .mean() \
    .sort_values('stylistic_quality_int', ascending=True) \
    .head(5).index[0]
lowest_stylistic_quality_model = ratings[ratings['report_id'] == report_id].sort_values(by=['user_id'])

# %%
print('Model:')
print(lowest_stylistic_quality_model.iloc[i]['predicted_impression'])
for i in range(5):
    print('-'*40)
    print('Radiologist', i+1)
    print('-'*40)
    print('-'*40)
    print('Edited:')
    print(lowest_stylistic_quality_model.iloc[i]['edited_impression'])
    print('-'*40)
    print('Stylistic Quality: ', lowest_stylistic_quality_model.iloc[i]['stylistic_quality_int'], '/ 4')
    print('Edit Time: ', lowest_stylistic_quality_model.iloc[i]['edit_time'])
    print('ROUGE-L: ', lowest_stylistic_quality_model.iloc[i]['rouge_L'])
# Out:
# Model:
# 1. Bilateral linear opacities, left much greater than right. Also noted is peripheral bilateral hemithorax consolidation/pleural thickening, left much greater than right, with decreased left lung volume. Suspect mild bronchial distortion and bronchiectasis with associated small consolidation at the left lung base (series 3, image 707).
# 2. Pulmonary nodules measuring up to 4 mm right upper lobe and 4 mm right lower lobe lung nodules. Recommend attention on follow-up.
# 3. Bulky bilateral axillary adenopathy with the largest lymph node measuring up to 1.5 cm in short axis on the right in the largest inguinal lymph node measuring up to 1.4 cm in short axis on the right. Scattered prominent mesenteric and retroperitoneal lymph nodes.
# ----------------------------------------
# Radiologist 1
# ----------------------------------------
# ----------------------------------------
# Edited:
# 1. Bilateral parenchymal findings to suggest infection or aspiration.
# 2. Pulmonary nodules measuring up to 4 mm, indeterminate for metastasis.
# 3. Bulky bilateral axillary adenopathy with the largest lymph node measuring up to 1.5 cm in short axis on the right in the largest inguinal lymph node measuring up to 1.4 cm in short axis on the right. Scattered prominent mesenteric and retroperitoneal lymph nodes.Findings are concerning for metastasis, lymphoma or sarcoidosis.
# ----------------------------------------
# Stylistic Quality:  2 / 4
# Edit Time:  87.41
# ROUGE-L:  0.5906735751295337
# ----------------------------------------
# Radiologist 2
# ----------------------------------------
# ----------------------------------------
# Edited:
# 1. Left greater than right pleural thickening and interstitial opacities concerning for lymphangitic spread of disease.
# 2. Multistation lymphadenopathy involving the bilateral axillary, inguinal, and iliac chain lymph nodes as well as mesenteric and retroperitoneal lymph nodes.
# 3. Pulmonary nodules measuring up to 4 mm right upper lobe and 4 mm right lower lobe lung nodules. Recommend attention on follow-up.
#
# ----------------------------------------
# Stylistic Quality:  2 / 4
# Edit Time:  93.29
# ROUGE-L:  0.3687150837988827
# ----------------------------------------
# Radiologist 3
# ----------------------------------------
# ----------------------------------------
# Edited:
# 1. Peripheral bilateral hemithorax consolidation/pleural thickening, greatest on the left. Attention on follow-up.
# 2. Pulmonary nodules measuring up to 4 mm right upper lobe and 4 mm right lower lobe lung nodules. Recommend attention on follow-up.
# 3. Thoracoabdominal adenopathy as above.
# ----------------------------------------
# Stylistic Quality:  2 / 4
# Edit Time:  61.67
# ROUGE-L:  0.4320987654320987
# ----------------------------------------
# Radiologist 4
# ----------------------------------------
# ----------------------------------------
# Edited:
# 1. Bilateral linear opacities, left much greater than right. Also noted is peripheral bilateral hemithorax consolidation/pleural thickening, left much greater than right, with decreased left lung volume. Suspect mild bronchial distortion and bronchiectasis with associated small consolidation at the left lung base (series 3, image 707).
# 2. Pulmonary nodules measuring up to 4 mm right upper lobe and 4 mm right lower lobe lung nodules. Recommend attention on follow-up.
# 3. Bulky bilateral axillary adenopathy with the largest lymph node measuring up to 1.5 cm in short axis on the right in the largest inguinal lymph node measuring up to 1.4 cm in short axis on the right. Scattered prominent mesenteric and retroperitoneal lymph nodes.
# ----------------------------------------
# Stylistic Quality:  3 / 4
# Edit Time:  0.0
# ROUGE-L:  1.0
# ----------------------------------------
# Radiologist 5
# ----------------------------------------
# ----------------------------------------
# Edited:
# 1. Pulmonary nodules measuring up to 4 mm are nonspecific. Recommend attention on follow-up.
# 2. Bulky bilateral axillary adenopathy with the largest lymph node measuring up to 2.9 cm in short axis in the left axilla. Additional scattered prominent mesenteric and retroperitoneal lymph nodes.
# ----------------------------------------
# Stylistic Quality:  2 / 4
# Edit Time:  92.62
# ROUGE-L:  0.4634146341463415

# %%
for i in range(5):
    print('-'*40)
    print('Radiologist', i+1)
    print('-'*40)
    print('Model:')
    print(lowest_stylistic_ratings.iloc[i]['predicted_impression'])
    print('-'*40)
    print('Edited:')
    print(lowest_stylistic_ratings.iloc[i]['edited_impression'])
    print('-'*40)
    print('Stylistic Quality: ', lowest_stylistic_ratings.iloc[i]['stylistic_quality_int'], '/ 4')
    print('Edit Time: ', lowest_stylistic_ratings.iloc[i]['edit_time'])
    print('ROUGE-L: ', lowest_stylistic_ratings.iloc[i]['rouge_L'])
# Out:
# ----------------------------------------
# Radiologist 1
# ----------------------------------------
# Model:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[51], line 6
#       4 print('-'*40)
#       5 print('Model:')
# ----> 6 print(lowest_stylistic_ratings.iloc[i]['predicted_impression'])
#       7 print('-'*40)
#       8 print('Edited:')
#
# NameError: name 'lowest_stylistic_ratings' is not defined

# %% [markdown]
# ## FIGURE 5

# %%
frankly_misleading = ratings[ratings['clinical_accuracy_int'] == 1].sort_values(by=['report_id', 'user_id'])
for i in range(len(frankly_misleading)):
    print('='*40)
    print('Pathology: ', frankly_misleading.iloc[i]['Pathology'])
    print('-'*40)
    print('Original: ', frankly_misleading.iloc[i]['original'])
    print('-'*40)
    if frankly_misleading.iloc[i]['original'] == 0:
        print('Model:')
        print(frankly_misleading.iloc[i]['predicted_impression'])
    else:
        print('Original:')
        print(frankly_misleading.iloc[i]['original_impression'])
    print('-'*40)
    print('Edited:')
    print(frankly_misleading.iloc[i]['edited_impression'])
    print('ROUGE-L:')
    print(frankly_misleading.iloc[i]['rouge_L'])
# Out:
# ========================================
# Pathology:  Acute/Emergent
# ----------------------------------------
# Original:  0
# ----------------------------------------
# Model:
# 1. Compared to 5/17/2022, increased size of enlarged supraclavicular and mediastinal lymph nodes.
# 2. New small right and trace left pleural effusions with adjacent atelectasis.
# ----------------------------------------
# Edited:
# 1. Findings compatible with volume overload including small right and trace left pleural effusions and mild interstitial edema.
# 2. Increased size of mediastinal and supraclavicular lymph nodes which may be related to volume status however attention on subsequent reimaging.
# ROUGE-L:
# 0.24242424242424246
# ========================================
# Pathology:  Acute/Emergent
# ----------------------------------------
# Original:  0
# ----------------------------------------
# Model:
# 1. Compared to 5/17/2022, increased size of enlarged supraclavicular and mediastinal lymph nodes.
# 2. New small right and trace left pleural effusions with adjacent atelectasis.
# ----------------------------------------
# Edited:
# 1. New mild pulmonary edema.
# 2. Compared to 5/17/2022, increased size of enlarged supraclavicular and mediastinal lymph nodes.
# 2. New small right and trace left pleural effusions with adjacent atelectasis.
# ROUGE-L:
# 0.9152542372881356
# ========================================
# Pathology:  Cancer Staging
# ----------------------------------------
# Original:  0
# ----------------------------------------
# Model:
# 1. No evidence of hypermetabolic malignancy.
# 2. Focal periportal hypermetabolism possibly correlating to a 7 mm periportal lymph node. Additional borderline focus of uptake (Se/Im 3076/118) to an aortocaval lymph node (Se/206/52). Recommend attention on follow-up imaging.
# 3. For further detail on simultaneously acquired PET/CT, see separately dictated report.
# ----------------------------------------
# Edited:
# 1. Mild hypermetabolic associated with a periportal and aortocaval lymph node. Findings are nonspecific and may be reactive to adjacent inflammation however attention on follow up imaging.
# 2. Post surgical changes of bilateral mastectomies and left axillary lymph node dissection with mild post surgical inflammation.
# 3. For further detail on simultaneously acquired PET/CT, see separately dictated report.
# ROUGE-L:
# 0.44247787610619466
# ========================================
# Pathology:  Interstitial Lung Disease
# ----------------------------------------
# Original:  1
# ----------------------------------------
# Original:
# 1. Unchanged lower lung predominant severe interstitial lung disease in the nonspecific interstitial pneumonia pattern.
# ----------------------------------------
# Edited:
# 1. Unchanged lower lung predominant interstitial lung disease compatible with desquamative interstitial pneumonia.
# ROUGE-L:
# 0.7142857142857142
# ========================================
# Pathology:  Cancer Staging
# ----------------------------------------
# Original:  1
# ----------------------------------------
# Original:
# 1. Slight increase in size of ulcerated soft tissue thickening of the mid esophagus with apparent focal defect connecting into the right lower lobe, concerning for bronchoesophageal fistula. This finding can be further evaluated with direct visualization or CT/fluoroscopic esophagram.
# 2. Slight increase in size in right-sided pulmonary nodules, concerning for worsening disease.
# 3. Multiple tubular areas of hypoattenuation within the right middle and right lower lobe, concerning for aspiration pneumonia. Background of basal predominant bronchiectasis is not significantly changed.
# ----------------------------------------
# Edited:
# 1. Continued worsening in extensive wall thickening of the mid esophagus with ulceration into the right lung. No significant change multiple pulmonary nodules some of which are necrotic.
# 2. Worsening right middle and lower lobe consolidations with areas of likely central necrosis concerning for necrotic pneumonia vs necrotic tumor.
# ROUGE-L:
# 0.33587786259541985
# ========================================
# Pathology:  Cancer Staging
# ----------------------------------------
# Original:  1
# ----------------------------------------
# Original:
# 1. Slight increase in size of ulcerated soft tissue thickening of the mid esophagus with apparent focal defect connecting into the right lower lobe, concerning for bronchoesophageal fistula. This finding can be further evaluated with direct visualization or CT/fluoroscopic esophagram.
# 2. Slight increase in size in right-sided pulmonary nodules, concerning for worsening disease.
# 3. Multiple tubular areas of hypoattenuation within the right middle and right lower lobe, concerning for aspiration pneumonia. Background of basal predominant bronchiectasis is not significantly changed.
# ----------------------------------------
# Edited:
# 1. Slight increase in size of ulcerated soft tissue thickening of the mid esophagus with apparent focal defect connecting into the right lower lobe, concerning for bronchoesophageal fistula. This finding can be further evaluated with direct visualization or CT/fluoroscopic esophagram.
# 2. Stable centrally necrotic pulmonary nodules.
# 3. Slight worsening in multiple tubular areas of hypoattenuation within the right middle and right lower lobe, concerning for aspiration pneumonia. Background of basal predominant bronchiectasis is not significantly changed.
# ROUGE-L:
# 0.8930817610062892
# ========================================
# Pathology:  Acute/Emergent
# ----------------------------------------
# Original:  1
# ----------------------------------------
# Original:
# 1. Bilateral lower lobe predominant groundglass opacities and nodular consolidation with associated bronchial wall thickening and distal airways impaction suggestive of aspiration/infection and less likely pulmonary involvement of amyloidosis.
# 2. Biatrial enlargement with ectatic ascending aorta measuring up to 42 mm. Enlarged main pulmonary artery measuring up to 34 mm.
# 3. Bilateral small pleural effusions.
# ----------------------------------------
# Edited:
# 1. Dependent nodular consolidation and impacted airways suggestive of aspiration/infection.
# 2. Cardiomegaly with ectatic ascending aorta measuring up to 42 mm. Enlarged main pulmonary artery measuring up to 34 mm.
#
# ROUGE-L:
# 0.6436781609195402
# ========================================
# Pathology:  Acute/Emergent
# ----------------------------------------
# Original:  1
# ----------------------------------------
# Original:
# 1. Bilateral lower lobe predominant groundglass opacities and nodular consolidation with associated bronchial wall thickening and distal airways impaction suggestive of aspiration/infection and less likely pulmonary involvement of amyloidosis.
# 2. Biatrial enlargement with ectatic ascending aorta measuring up to 42 mm. Enlarged main pulmonary artery measuring up to 34 mm.
# 3. Bilateral small pleural effusions.
# ----------------------------------------
# Edited:
# 1. Pulmonary findings suggest aspiration/infection.
# 2. Biatrial enlargement with ectatic ascending aorta measuring up to 42 mm. Enlarged main pulmonary artery, which can be seen in pulmonary hypertension.
# 3. Small bilateral pleural effusions.
# ROUGE-L:
# 0.5111111111111111
# ========================================
# Pathology:  Acute/Emergent
# ----------------------------------------
# Original:  0
# ----------------------------------------
# Model:
# 1. Compared to 1/26/2022, no significant change in extensive lower lobe predominant groundglass and peribronchovascular reticulation with associated traction bronchiectasis/bronchiolectasis. Findings are most consistent with UIP pattern interstitial lung disease.
# ----------------------------------------
# Edited:
# 1. Compared to 1/26/2022, no significant change in extensive lower lobe predominant groundglass and peribronchovascular reticulation with associated traction bronchiectasis/bronchiolectasis. Findings are most consistent with and NSIP pattern interstitial lung disease which may be due to underlying connective tissue disease given patulous appearance of the esophagus.
# ROUGE-L:
# 0.7804878048780488
# ========================================
# Pathology:  Acute/Emergent
# ----------------------------------------
# Original:  0
# ----------------------------------------
# Model:
# 1. Compared to 1/26/2022, no significant change in extensive lower lobe predominant groundglass and peribronchovascular reticulation with associated traction bronchiectasis/bronchiolectasis. Findings are most consistent with UIP pattern interstitial lung disease.
# ----------------------------------------
# Edited:
# 1. Compared to 1/26/2022, unchanged extent of NSIP pattern interstitial lung disease.
# ROUGE-L:
# 0.42553191489361697
# ========================================
# Pathology:  Nodules
# ----------------------------------------
# Original:  0
# ----------------------------------------
# Model:
# 1. Juxtapleural mixed solid and groundglass opacity with possible internal cystic change in the left lower lobe measuring approximately 2.3 x 1.3 cm (Se/Im 3/120), which may represent a small focus of infection or inflammation. Recommend follow-up CT in 3 months to evaluate for interval resolution.
# 2. 5 mm right upper lobe groundglass nodule (Se/Im 3/40). Recommend follow-up CT in 3 months.
# 3. 4 mm superior segment left lower lobe groundglass nodule (Se/Im 3/88), possibly a pulmonary adenocarcinoma in situ.
# ----------------------------------------
# Edited:
# 1. Left lower lobe solid-groundglass-cystic nodule is suspicious for primary invasive adenocarcinoma. Advise attention on follow-up.
# 2. Tiny groundglass nodules in the right upper and left lower lobes could represent adenocarcinoma in situ.
# ROUGE-L:
# 0.22222222222222218
# ========================================
# Pathology:  Cancer Staging
# ----------------------------------------
# Original:  0
# ----------------------------------------
# Model:
# 1. Compared to 9/3/2021, decreased size and hypermetabolism of the left breast nodule.
# 2. New focus of hypermetabolism in the left iliac wing without CT correlate, nonspecific. Attention on follow-up.
# 3. For further detail on simultaneously acquired PET/CT, see separately dictated report.
# ----------------------------------------
# Edited:
# 1. Multiple subsegmental pulmonary emboli.
# 2. New focus of hypermetabolism in the left iliac wing without CT correlate, concerning for new osseous metastatic disease. No significant change in two left breast soft tissue lesions with associated mild hypermetabolism.
# 3. Diffuse colonic hypermetabolism with fluid in the distal colon which can be seen in colitis, recommend correlation with patient symptoms
# 4. For further detail on simultaneously acquired PET/CT, see separately dictated report.
# ROUGE-L:
# 0.45762711864406785
# ========================================
# Pathology:  Cancer Staging
# ----------------------------------------
# Original:  0
# ----------------------------------------
# Model:
# 1. Compared to 9/3/2021, decreased size and hypermetabolism of the left breast nodule.
# 2. New focus of hypermetabolism in the left iliac wing without CT correlate, nonspecific. Attention on follow-up.
# 3. For further detail on simultaneously acquired PET/CT, see separately dictated report.
# ----------------------------------------
# Edited:
# 1. Compared to 9/3/2021, increased size and hypermetabolism of the indexed left breast nodule.
# 2. New focus of hypermetabolism in the left iliac wing without CT correlate, nonspecific. Attention on follow-up.
# 3. For further detail on simultaneously acquired PET/CT, see separately dictated report.
# ROUGE-L:
# 0.967741935483871

# %% [markdown]
# ## FIGURE 6 - ROUGE Case Studies

# %%
# id: 289, report_id: 48, user_id: 3
# Clinical: 4, Stylistic: 2
# ratings[ratings['id'] == 289]

# id: 115, report_id: 44, user_id: 2
# Clinical: 4, Stylistic: 4
# ratings[ratings['id'] == 115]

# id: 79, report_id: 8, user_id: 2
# Clinical: 1, Stylistic: 2
# ratings[ratings['id'] == 79]

# id: 147, report_id: 26, user_id: 5
# Clinical: 1, Stylistic: 2
# ratings[ratings['id'] == 147]

# %% [markdown]
# ## Intraclass Correlation

# %%
ICC_data = ratings[['report_id', 'user_id', 'clinical_accuracy_int']]
icc = pg.intraclass_corr(data=ICC_data, targets='report_id', raters='user_id',
                         ratings='clinical_accuracy_int').round(3)
icc.set_index("Type")
# Out:
#                    Description    ICC      F  df1  df2  pval         CI95%
# Type
# ICC1    Single raters absolute  0.230  2.493   59  240   0.0  [0.12, 0.36]
# ICC2      Single random raters  0.250  3.014   59  236   0.0  [0.14, 0.38]
# ICC3       Single fixed raters  0.287  3.014   59  236   0.0  [0.17, 0.42]
# ICC1k  Average raters absolute  0.599  2.493   59  240   0.0  [0.41, 0.74]
# ICC2k    Average random raters  0.625  3.014   59  236   0.0  [0.45, 0.76]
# ICC3k     Average fixed raters  0.668  3.014   59  236   0.0  [0.51, 0.78]

# %%
ICC_data = ratings[['report_id', 'user_id', 'stylistic_quality_int']]
icc = pg.intraclass_corr(data=ICC_data, targets='report_id', raters='user_id',
                         ratings='stylistic_quality_int').round(3)
icc.set_index("Type")
# Out:
#                    Description    ICC      F  df1  df2   pval         CI95%
# Type
# ICC1    Single raters absolute  0.114  1.642   59  240  0.005  [0.02, 0.23]
# ICC2      Single random raters  0.157  2.303   59  236  0.000  [0.06, 0.28]
# ICC3       Single fixed raters  0.207  2.303   59  236  0.000   [0.1, 0.34]
# ICC1k  Average raters absolute  0.391  1.642   59  240  0.005   [0.11, 0.6]
# ICC2k    Average random raters  0.482  2.303   59  236  0.000  [0.25, 0.66]
# ICC3k     Average fixed raters  0.566  2.303   59  236  0.000  [0.36, 0.72]

# %%
ratings['grammatical_accuracy_int'].var()
# Out:
# 0.09828316610925306

# %%
np.__version__
# Out:
# '1.26.4'
